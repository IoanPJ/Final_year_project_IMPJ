# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import logistic

# %%
loclogistic=0.5576534855181654
scalelogistic=0.1297154573839233
statisticlogistic=4.904726368010678

xs = np.arange(0,1,0.01)

plt.plot(xs,logistic.pdf(xs,loclogistic,scalelogistic))
plt.plot(loclogistic*np.ones(20),np.linspace(0,2.2,20))
